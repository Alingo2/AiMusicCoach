# %%
import numpy as np
import math
import json

# %%
y=[[1,1],[2,2],[3,3]]
y=np.array(y)
ylen0=y.shape[0]
ylen1=y.shape[1]
print(ylen0)
print(ylen1)
# Out:
# 3
# 2

# %%
x=[[0, 0.5],[5, 0.5],[9, 0.5],[5, 0.5],[0, 0.5],[2, 0.5],[9, 0.5],[5, 0.5],[0, 0.5],
[2, 0.5], [9, 0.5],[5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5],[9, 0.5],
[5, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5],[5, 0.5],[2, 0.5],[5, 0.5],
[6, 0.5], [2, 0.5], [0, 0.5], [5,  0.5], [9, 0.5],[5, 0.5],[0, 0.5],[2, 0.5],[9, 0.5],
[5, 0.5], [2, 0.5], [9, 0.5],[5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5],[0, 0.5],
[5, 0.5], [9, 0.5],[5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5],
[5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6,  0.5], [0, 0.5],[9, 0.5], [9, 0.5], [5, 0.5], 
[5, 1], [6, 0.5], [7,  1], [9, 0.5], [9, 0.5], [5, 0.5], [5, 0.5], [6, 0.25], [7,  0.25], 
[6, 0.5], [5, 0.5], [0, 0.5], [9, 0.5], [9, 0.5], [5,  0.5], [5, 1], [6, 0.5], [7, 1], 
[7, 1], [7, 0.5], [8, 0.25],[7,  0.25], [6, 0.25], [8, 0.25], [7, 0.5], [5, 0.5], [0, 0.5],
[7,  0.5], [7, 0.5], [7, 0.5], [8, 0.5], [7, 0.5], [6, 0.5], [5,  0.25], [6, 0.25], [7, 0.5],
[7, 0.5], [7, 0.5], [7, 0.5], [6,  0.25], [7, 0.25], [6, 0.5], [5, 1], [3, 0.5], [4.5, 0.5],
[5, 0.5], [7, 0.5], [8, 0.5], [7, 0.5], 6, 0.5], [5, 0.25], [6, 0.25], [7, 0.5], [7, 0.5],
[7, 0.5], [7, 0.5], [6, 0.25], [7,  0.25], [6, 0.5], [5, 1], [5, 1], [0, 0.25], [-1, 0.25],
[5, 0.25], [4, 0.25], [5, 0.25],[5, 0.5], [1, 0.25,], [5, 1], [4.5,   0.25], [5, 1], [0, 0.25], 
[2, 0.25], [5, 0.25], [6, 0.25], [6,   0.25], [7, 0.5], [9, 0.5], [2, 0.25], [6, 0.5], [9, 1],
[0,   0.25], [2, 0.5], [9, 0.5], [2, 0.5], [9, 0.5], [8, 0.25], [7,   0.25], [6, 0.25], [7, 1.5],
[2, 0.5], [5, 0.5], [2, 0.5], [5,   0.5], [5, 0.25], [4.5, 0.25], [3, 0.5], [4, 0.5], [5, 0.5], 
[9,   0.5], [8, 0.5], [7, 0.5], [5, 0.5], [5, 2.5], [0, 0.5], [2,   0.5], [5, 0.5], [4, 0.5],
[3, 0.5], [4, 0.5], [5, 0.5], [9,  0.5], [8, 0.5], [7, 0.5], [5, 0.5], [5, 2.5], [2, 0.5],
[5,  0.5], [6, 1], [9, 1], [7, 0.5], [6, 0.5], [8, 0.5], [7, 1], [5,  0.5], [9, 0.5], [11.5, 0.5],
[12, 0.5], [11, 0.5], [9, 0.5], [5, 1], [5, 0.5], [10, 0.5], [10, 1], [10, 0.5], [9, 0.5], [9, 1], 
[9, 0.5], [8, 0.5], [7, 0.5], [6, 0.5], [7, 0.5], [8, 0.5], [7, 2.5], [7, 0.5], [8.5, 0.5], [9.5, 0.5],
[7, 1], [8.5, 0.5], [9.5, 0.5], [11.5, 0.5], [13, 0.5], [11.5, 0.5], [12, 0.5], [12, 1.5], [0,0.5],
[12, 0.5], [12, 0.5], [9, 0.5], [9, 0.5], [10, 0.5], [9, 0.5], [8, 0.5], [6, 0.5], [7, 0.5], [8, 0.5],
[9, 0.5], [10,  0.5], [5, 0.5], [10, 1], [11.5, 1], [7, 0.5], [6, 0.5], [8, 0.5], [7, 1], [5, 0.5],
[9, 0.5], [11.5, 0.5], [12, 0.5], [11.5, 0.5], [9, 0.5], [5, 1], [5, 0.5], [10, 0.5], [10, 1], [10, 0.5],
[9,0.5], [9, 1], [9, 0.5], [8, 0.5], [7, 0.5], [6, 0.5], [7, 0.5], [8,0.5], [7, 2.5], [7, 0.5], [8.5, 0.5],
[9.5, 0.5], [7, 1], [8.5, 0.5], [9.5, 0.5], [11.5, 0.5], [13, 0.5], [11.5, 0.5], [12, 0.5], [12, 1.5],
[0, 0.5], [12, 0.5], [12, 0.5], [9, 0.5], [9, 0.5], [10, 0.5], [9, 0.5], [8, 0.5], [3, 0.5], [4, 0.5], 
[5, 0.5], [6, 0.5], [7, 0.5], [6, 1.5], [7, 0.5], [6, 0.5], [5, 1], [9, 0.5], [5, 1], [2, 0.5], 
[9, 0.5], [5, 0.25], [6, 0.25], [5, 1], [9, 0.5], [5, 1], [9, 0.5], [12, 0.5], [11.5, 0.5], [9, 1],
[9,  0.5], [5, 1], [2, 0.5], [5, 0.5], [6, 0.5], [5, 1], [9, 0.5], [5, 1], [2, 0.5], [6, 0.5], 
[5, 0.25], [4, 0.25]]
xlen0=x.shape[0]
xlen1=x.shape[1]
print(xlen0)
print(xlen1)
# Out:
#   File "<ipython-input-51-3da327b1e2f3>", line 34
#     [5, 0.25], [4, 0.25]]
#                         ^
# SyntaxError: invalid syntax

# %%
x=open("./test/json/sunny.json")
# x=np.array(x)
print(x[5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-ac26361b1012> in <module>()
#       1 x=open("./test/json/sunny.json")
#       2 # x=np.array(x)
# ----> 3 print(x[5])
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
x=[[0, 0.5],[5, 0.5],[9, 0.5],[5, 0.5],[0, 0.5],[2, 0.5],[9, 0.5],[5, 0.5], [0, 0.5],
   [0, 0.5],[5, 0.5],[9, 0.5],[5, 0.5], [0, 0.5],[2, 0.5],[9, 0.5],[5, 0.5], [0, 0.5],
[5, 0.25],   [4, 0.25]]
x=np.array(x)

# %%
x=[[0, 0.5],[5, 0.5],[9, 0.5],[5, 0.5],[0, 0.5],[2, 0.5],[9, 0.5],[5, 0.5],[0, 0.5],
[2, 0.5], [9, 0.5],[5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.
[9, 0.5], [8, 0.5], [7, 0.5], [6, 0.5], [7, 0.5], [8, 0.5], [7, 2.5], [7, 0.5], [8.5, 0.5], [9.5, 0.5],
[7, 1], [8.5, 0.5], [9.5, 0.5], [11.5, 0.5], [13, 0.5], [11.5, 0.5], [12, 0.5], [12, 1.5], [0,0.5],
[12, 0.5], [12, 0.5], [9, 0.5], [9, 0.5], [10, 0.5], [9, 0.5], [8, 0.5], [6, 0.5], [7, 0.5], [8, 0.5],
[9, 0.5], [10,  0.5], [5, 0.5], [10, 1], [11.5, 1], [7, 0.5], [6, 0.5], [8, 0.5], [7, 1], [5, 0.5],
[9, 0.5], [11.5, 0.5], [12, 0.5], [11.5, 0.5], [9, 0.5], [5, 1], [5, 0.5], [10, 0.5], [10, 1], [10, 0.5],
[9,0.5], [9, 1], [9, 0.5], [8, 0.5], [7, 0.5], [6, 0.5], [7, 0.5], [8,0.5], [7, 2.5], [7, 0.5], [8.5, 0.5],
[9.5, 0.5], [7, 1], [8.5, 0.5], [9.5, 0.5], [11.5, 0.5], [13, 0.5], [11.5, 0.5], [12, 0.5], [12, 1.5],
[0, 0.5], [12, 0.5], [12, 0.5], [9, 0.5], [9, 0.5], [10, 0.5], [9, 0.5], [8, 0.5], [3, 0.5], [4, 0.5], 
[5, 0.5], [6, 0.5], [7, 0.5], [6, 1.5], [7, 0.5], [6, 0.5], [5, 1], [9, 0.5], [5, 1], [2, 0.5], 
[9, 0.5], [5, 0.25], [6, 0.25], [5, 1], [9, 0.5], [5, 1], [9, 0.5], [12, 0.5], [11.5, 0.5], [9, 1],
[9,  0.5], [5, 1], [2, 0.5], [5, 0.5], [6, 0.5], [5, 1], [9, 0.5], [5, 1], [2, 0.5], [6, 0.5], 
[5, 0.25], [4, 0.25]]
x=np.array(x)
len1=x.shape[0]
len2=x.shape[1]
print(len1,len2,x[310][0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-5401d323c0ed> in <module>()
#      34 [5, 0.25], [4, 0.25]]
#      35 #x=np.array(x)
# ---> 36 len1=x.shape[0]
#      37 len2=x.shape[1]
#      38 print(len1,len2,x[310][0])
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
N=20
train_x=[]
output_1=[]
output_2=[]
for i in range(0,len1-N-1):
    b=x[i:i+20]
    train_x.append(b)
    output_1.append(x[i+21][0])
    output_2.append(x[i+21][1])
train_x=list(train_x)   
#output_1=np.array(output_1)
#output_2=np.array(output_2)
#print(train_x)
print("train_x:",train_x)
print("output_1:",output_1)
print("output_2:",output_2)
# Out:
# train_x: [[[0, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5]], [[5, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5]], [[9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [5, 0.5]], [[5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5]], [[0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [5, 0.5],
# ...

# %%
with open("./test/json/sunny_output1.json","w") as f:
        json.dump(output_1,f)
with open("./test/json/sunny_output2.json","w") as f:
        json.dump(output_2,f)
with open("./test/json/sunny_train.json","w") as f:
        json.dump(train_x,f)
