# %%
from keras.layers import Embedding,LSTM,Dense,SimpleRNN
from keras import models
from keras import layers
import numpy as np
import json

# %%
model = models.Sequential()
model.add(layers.GRU(10))
model.add(Dense(1))

# %%
obj_r=open("./test/json/sunny_train.json")
input_train = json.load(obj_r)
print(input_train)
# Out:
# [[[0, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5]], [[5, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5]], [[9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [5, 0.5]], [[5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5]], [[0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [0, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [2, 0.5], [6, 0.5], [5, 0.5], [9, 0.5], [5, 0.5], [2, 0.5], [9, 0.5], [5, 0.5], [2, 0.5]
# ...

# %%
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %%
history=model.fit(input_train,output_train_1,batch_size=1,epochs=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f87d5f4661ad> in <module>()
# ----> 1 history=model.fit(input_train,output_train_1,batch_size=1,epochs=50)
#
# D:\MyCode\Anaconda\envs\AiMusic\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1087             sample_weight=sample_weight,
#    1088             class_weight=class_weight,
# -> 1089             batch_size=batch_size)
#    1090
#    1091         # Prepare validation data.
#
# D:\MyCode\Anaconda\envs\AiMusic\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
# ...

# %%
input_test=[[[7,1],[8,1],[7,1],[8,0.5],[5,1],[7,1],[8,1],[7,1],[8,0.5],[5,1]],
            [[7,1],[8,1],[7,1],[8,0.5],[5,1],[7,1],[8,1],[7,1],[8,0.5],[5,1]]]
input_test=np.array(input_test)

# %%
print(model.predict(input_test))
