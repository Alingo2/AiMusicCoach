# %%
from keras import models
from keras import layers
import numpy as np

# %%
input_train=[
             [[0.1,1],[0.2,1],[0.3,1],[0.4,0.8],[0.5,0.67],[0.61,0.5],[0.71,0.71],[0.8,1],[0,0],[0,0]],
              [[0.1,1],[0.2,1],[0.3,1],[0.4,0.8],[0.5,0.67],[0.61,0.5],[0.71,0.71],[0.8,1],[0,0],[0,0]],
#              [[],[],[],[],[],[],[],[],[],[]],
#              [[],[],[],[],[],[],[],[],[],[]],
#              [[],[],[],[],[],[],[],[],[],[]],
#              [[],[],[],[],[],[],[],[],[],[]],
#              [[],[],[],[],[],[],[],[],[],[]]
            ]
y_train=[0.1,0.1]
# input_test=
# y_test=
input_train=np.array(input_train)
y_train=np.array(y_train)
# input_test=np.array(input_test)
# y_test=np.array(y_test)
train_sample=input_train.shape[0]
# test_sample=input_train.shape[0]
print(train_sample)
# Out:
# 2

# %%
input_train=input_train.reshape((train_sample,2*10))

# %%
model = models.Sequential()
model.add(layers.Dense(8,activation='relu',input_shape=(2*10,)))
model.add(layers.Dense(1))

# %%
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %%
history=model.fit(input_train,y_train,batch_size=2,epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6658 - mean_absolute_error: 0.8160
# Epoch 2/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.5552 - mean_absolute_error: 0.7451
# Epoch 3/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.4848 - mean_absolute_error: 0.6962
# Epoch 4/100
# 2/2 [==============================] - 0s 1ms/step - loss: 0.4311 - mean_absolute_error: 0.6566
# Epoch 5/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3871 - mean_absolute_error: 0.6222
# Epoch 6/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3498 - mean_absolute_error: 0.5914
# Epoch 7/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3172 - mean_absolute_error: 0.5632
# Epoch 8/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2883 - mean_absolute_error: 0.5370
# Epoch 9/100
# ...
